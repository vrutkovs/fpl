# %%
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None
pd.set_option("display.precision", 3)
pd.set_option('future.no_silent_downcasting', True)

# %%
from football import defender
from football import main

affordable_defs = defender.affordable_defs_for_year(main.start_year)

for x in range(main.start_year+1, main.current_year+1):
  second_df = defender.affordable_defs_for_year(x)
  affordable_defs = pd.merge(
      left=affordable_defs,
      right=second_df,
      how='outer',
      left_on=['first_name', 'second_name'],
      right_on=['first_name', 'second_name'],
  )

# Drop NA in any of two columns
# filters out unavailable now
# filter out newcomers with outlying results
last_year = main.current_year - 1
affordable_defs.dropna(subset=[last_year, main.current_year], inplace=True)

affordable_defs = affordable_defs.apply(main.chance_of_playing_this_round, axis=1)
affordable_defs.dropna(subset=["chance_to_play"], inplace=True)

unavailable_defs = affordable_defs[affordable_defs["chance_to_play"] < 75]
affordable_defs.drop(unavailable_defs.index, inplace=True)

# # Show top 10 Defs w/ precision set to 1
affordable_defs.sort_values(by=last_year, ascending=False, inplace=True)
affordable_defs
# Out:
#     first_name            second_name     2020     2021     2022     2023  \
# 377    William                 Saliba      NaN      NaN   96.600  117.931
# 176       John                 Stones  161.083  186.167  108.471  117.889
# 148      Jakub                 Kiwior      NaN      NaN   70.833  117.750
# 117    Gabriel  dos Santos MagalhÃ£es      NaN      NaN   79.279  117.000
# 39    Benjamin                  White      NaN      NaN   87.257  114.885
# ..         ...                    ...      ...      ...      ...      ...
# 375  VladimÃ­r                 Coufal      NaN      NaN      NaN   44.786
# 196      Kenny                   Tete   54.704      NaN   71.361   41.095
# 76        Dara                 O'Shea   41.157      NaN      NaN   40.732
# 34         Ben                Johnson   51.600   77.611   66.154   33.625
# 262    Michael                  Keane   69.512   51.685   44.682   33.615
#
#         2024  chance_to_play
# 377  108.000             100
# 176  135.000             100
# 148   16.000             100
# 117  108.000             100
# 39   202.500             100
# ..       ...             ...
# 375   66.000             100
# 196  108.000             100
# 76    90.000             100
# 34    21.833             100
# 262   32.143             100
#
# [81 rows x 8 columns]

# %%
# Predict stat using previous data
from football import sklearn
predicted_defs = affordable_defs.copy().apply(sklearn.predict_this_year_linear, axis=1)

# Drop if prediction score is lower than 0.5 
# predicted_defs.drop(predicted_defs[predicted_defs["prediction_linear_score"] < 0].index, inplace=True)
# Sort by prediction
predicted_defs.sort_values(by="prediction_linear", ascending=False, inplace=True)
predicted_defs.head()
# Out:
#     first_name            second_name  2020  2021    2022     2023   2024  \
# 148      Jakub                 Kiwior   NaN   NaN  70.833  117.750   16.0
# 117    Gabriel  dos Santos MagalhÃ£es   NaN   NaN  79.279  117.000  108.0
# 39    Benjamin                  White   NaN   NaN  87.257  114.885  202.5
# 377    William                 Saliba   NaN   NaN  96.600  117.931  108.0
# 238     Manuel                 Akanji   NaN   NaN  99.304  109.217   90.0
#
#      chance_to_play  prediction_linear  prediction_linear_score
# 148             100            164.667                   -3.261
# 117             100            154.721                   -1.812
# 39              100            142.512                    0.503
# 377             100            139.262                   -3.289
# 238             100            119.130                   -3.594

# %%
predicted_defs_svr = predicted_defs.apply(sklearn.predict_this_year_svr, axis=1)

# Drop if prediction score is lower than 0
# predicted_defs.drop(predicted_defs[predicted_defs["prediction_svr_score"] < 0].index, inplace=True)
# Sort by prediction
predicted_defs_svr.sort_values(by="prediction_svr", ascending=False, inplace=True)
predicted_defs_svr.head()
# Out:
#     first_name      second_name     2020     2021     2022     2023   2024  \
# 176       John           Stones  161.083  186.167  108.471  117.889  135.0
# 325     RÃºben  Gato Alves Dias      NaN      NaN  124.812   91.321   91.2
# 62       Conor          Bradley      NaN      NaN      NaN  107.429   75.0
# 377    William           Saliba      NaN      NaN   96.600  117.931  108.0
# 238     Manuel           Akanji      NaN      NaN   99.304  109.217   90.0
#
#      chance_to_play  prediction_linear  prediction_linear_score  \
# 176             100             91.583                    0.079
# 325             100             57.830                   -0.484
# 62              100            107.429                   -1.000
# 377             100            139.262                   -3.289
# 238             100            119.130                   -3.594
#
#      prediction_svr  prediction_svr_score
# 176         138.997                 0.060
# 325         108.049                -0.040
# 62          107.429                -1.000
# 377         107.284                 0.175
# 238         104.279                -0.275

# %% [markdown]
# # Good holding defender

# %%
# Get current season stats to calculate performance
def_data = predicted_defs_svr.copy()
def_data = def_data.apply(defender.expected_vs_actual_goals_conceded, axis=1)

# Drop if performes much worse
def_data.drop(def_data[def_data["overperformed_goals"] < -1].index, inplace=True)
def_data.dropna(how='all', inplace=True)
def_data
# Out:
#     first_name          second_name     2020     2021     2022     2023  \
# 176       John               Stones  161.083  186.167  108.471  117.889
# 325     RÃºben      Gato Alves Dias      NaN      NaN  124.812   91.321
# 62       Conor              Bradley      NaN      NaN      NaN  107.429
# 377    William               Saliba      NaN      NaN   96.600  117.931
# 238     Manuel               Akanji      NaN      NaN   99.304  109.217
# ..         ...                  ...      ...      ...      ...      ...
# 243     Marcos               Senesi      NaN      NaN   45.255   50.886
# 161     Jarrad          Branthwaite      NaN   22.765      NaN   70.818
# 92     Emerson  Palmieri dos Santos      NaN      NaN   47.036   46.836
# 330   Santiago                Bueno      NaN      NaN      NaN   45.500
# 375  VladimÃ­r               Coufal      NaN      NaN      NaN   44.786
#
#         2024  chance_to_play  prediction_linear  prediction_linear_score  \
# 176  135.000             100             91.583                    0.079
# 325   91.200             100             57.830                   -0.484
# 62    75.000             100            107.429                   -1.000
# 377  108.000             100            139.262                   -3.289
# 238   90.000             100            119.130                   -3.594
# ..       ...             ...                ...                      ...
# 243   69.200             100             56.518                    0.487
# 161   90.000              75             94.845                    0.990
# 92    46.778             100             46.636                    0.451
# 330   21.000             100             45.500                   -1.000
# 375   66.000             100             44.786                   -1.000
#
#      prediction_svr  prediction_svr_score  overperformed_goals
# 176         138.997                 0.060                 0.06
# 325         108.049                -0.040                  NaN
# 62          107.429                -1.000                 0.04
# 377         107.284                 0.175                 0.47
# 238         104.279                -0.275                 1.01
# ..              ...                   ...                  ...
# 243          48.089                -0.443                -0.40
# 161          47.159                -0.208                -0.05
# 92           46.936                -0.227                 0.03
# 330          45.500                -1.000                 0.39
# 375          44.786                -1.000                  NaN
#
# [73 rows x 13 columns]

# %%
# mix in player stats
defs = main.player_type_for_year(main.current_year, player_type="DEF")
player_info = pd.merge(
      left=def_data,
      right=defs,
      how='left',
      left_on=['first_name', 'second_name'],
      right_on=['first_name', 'second_name'],
  )
player_custom_info = player_info[['first_name', 'second_name', main.current_year, 'prediction_linear', 'prediction_svr', 'overperformed_goals', 'now_cost', 'goals_conceded', 'minutes', 'assists', 'total_points', 'influence', 'creativity', 'bonus', 'bps','selected_by_percent', ]]
player_custom_info.head()
# Out:
#   first_name      second_name   2024  prediction_linear  prediction_svr  \
# 0       John           Stones  135.0             91.583         138.997
# 1     RÃºben  Gato Alves Dias   91.2             57.830         108.049
# 2      Conor          Bradley   75.0            107.429         107.429
# 3    William           Saliba  108.0            139.262         107.284
# 4     Manuel           Akanji   90.0            119.130         104.279
#
#    overperformed_goals  now_cost  goals_conceded  minutes  assists  \
# 0                 0.06        53               1      135        0
# 1                  NaN        55               5      456        0
# 2                 0.04        48               1       75        0
# 3                 0.47        60               5      540        0
# 4                 1.01        55               6      540        0
#
#    total_points  influence  creativity  bonus  bps  selected_by_percent
# 0             9       39.0         9.3      0   24                  1.7
# 1             9       79.4        61.1      0   52                  4.0
# 2             4       17.8         6.5      0   11                  0.3
# 3            20      106.0         5.6      0   93                 33.3
# 4            14      109.8       122.4      0   83                  5.1
