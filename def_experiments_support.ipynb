# %%
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None
pd.set_option("display.precision", 3)
pd.set_option('future.no_silent_downcasting', True)

# %%
from football import defender
from football import main

affordable_defs = defender.affordable_support_defs_for_year(main.start_year)

for x in range(main.start_year+1, main.current_year+1):
  second_df = defender.affordable_support_defs_for_year(x)
  affordable_defs = pd.merge(
      left=affordable_defs,
      right=second_df,
      how='outer',
      left_on=['first_name', 'second_name'],
      right_on=['first_name', 'second_name'],
  )

# Drop NA in any of two columns
# filters out unavailable now
# filter out newcomers with outlying results
last_year = main.current_year - 1
affordable_defs.dropna(subset=[last_year, main.current_year], inplace=True)

affordable_defs = affordable_defs.apply(main.chance_of_playing_this_round, axis=1)
affordable_defs.dropna(subset=["chance_to_play"], inplace=True)

unavailable_defs = affordable_defs[affordable_defs["chance_to_play"] < 75]
affordable_defs.drop(unavailable_defs.index, inplace=True)

# # Show top 10 Defs w/ precision set to 1
affordable_defs.sort_values(by=last_year, ascending=False, inplace=True)
affordable_defs
# Out:
#        first_name      second_name       2020       2021   2022   2023   2024  \
# 214        Kieran         Trippier        NaN  0.000e+00  0.003  0.004  0.000
# 216  Konstantinos         Tsimikas  0.000e+00  2.288e-03  0.005  0.004  0.000
# 64          Conor          Bradley        NaN        NaN    NaN  0.004  0.000
# 249          Malo            Gusto        NaN        NaN    NaN  0.003  0.000
# 157         Jakub           Kiwior        NaN        NaN  0.000  0.003  0.000
# ..            ...              ...        ...        ...    ...    ...    ...
# 381         Tosin       Adarabioyo  3.386e-04        NaN  0.000  0.000  0.000
# 332          Rico            Lewis        NaN        NaN  0.000  0.000  0.003
# 378          Tino       Livramento        NaN  9.091e-04  0.000  0.000  0.000
# 350      Santiago            Bueno        NaN        NaN    NaN  0.000  0.000
# 343        R̼ben  Gato Alves Dias        NaN        NaN  0.000  0.000  0.000
#
#      chance_to_play
# 214             100
# 216             100
# 64              100
# 249             100
# 157             100
# ..              ...
# 381             100
# 332             100
# 378             100
# 350             100
# 343             100
#
# [91 rows x 8 columns]

# %%
# Predict stat using previous data
from football import sklearn
predicted_defs = affordable_defs.copy().apply(sklearn.predict_this_year_linear, axis=1)

# Drop if prediction score is lower than 0.5 
# predicted_defs.drop(predicted_defs[predicted_defs["prediction_linear_score"] < 0].index, inplace=True)
# Sort by prediction
predicted_defs.sort_values(by="prediction_linear", ascending=False, inplace=True)
predicted_defs.head()
# Out:
#        first_name second_name  2020   2021   2022   2023  2024  \
# 216  Konstantinos    Tsimikas   0.0  0.002  0.005  0.004   0.0
# 214        Kieran    Trippier   NaN  0.000  0.003  0.004   0.0
# 157         Jakub      Kiwior   NaN    NaN  0.000  0.003   0.0
# 256        Marcos      Senesi   NaN    NaN  0.000  0.002   0.0
# 136         Harry     Toffolo   NaN    NaN  0.000  0.002   0.0
#
#      chance_to_play  prediction_linear  prediction_linear_score
# 216             100              0.007                   -1.239
# 214             100              0.007                   -2.274
# 157             100              0.006                   -5.000
# 256             100              0.004                   -5.000
# 136             100              0.004                   -5.000

# %%
predicted_defs_svr = predicted_defs.apply(sklearn.predict_this_year_svr, axis=1)

# Drop if prediction score is lower than 0
predicted_defs_svr.drop(predicted_defs_svr[predicted_defs_svr["prediction_svr_score"] < -0.5].index, inplace=True)
# predicted_defs_svr.drop(predicted_defs_svr[predicted_defs_svr["prediction_svr"] == 0].index, inplace=True)
# Sort by prediction
predicted_defs_svr.sort_values(by="prediction_svr", ascending=False, inplace=True)
predicted_defs_svr.head()
# Out:
#        first_name       second_name   2020   2021   2022   2023   2024  \
# 383         Trent  Alexander-Arnold  0.003  0.004  0.004  0.002  0.002
# 260          Matt           Doherty  0.002  0.006  0.000  0.000  0.000
# 19         Andrew         Robertson  0.002  0.004  0.003  0.001  0.000
# 216  Konstantinos          Tsimikas  0.000  0.002  0.005  0.004  0.000
# 311         Pedro             Porro    NaN    NaN  0.003  0.003  0.000
#
#      chance_to_play  prediction_linear  prediction_linear_score  \
# 383             100          2.884e-03                    0.148
# 260             100         -8.078e-04                    0.309
# 19              100          1.553e-03                    0.422
# 216             100          7.069e-03                   -1.239
# 311             100          2.528e-03                   -0.396
#
#      prediction_svr  prediction_svr_score
# 383           0.003                -0.103
# 260           0.003                -0.396
# 19            0.003                -0.140
# 216           0.003                -0.011
# 311           0.003                -0.500

# %% [markdown]
# # Good assisting defender

# %%
# Get current season stats to calculate performance
def_data = predicted_defs_svr.copy()
def_data = def_data.apply(defender.expected_vs_actual_assists, axis=1)

# Drop if performes much worse
def_data.drop(def_data[def_data["overperformed_assists"] < -1].index, inplace=True)
def_data.dropna(how='all', inplace=True)
def_data
# Out:
#        first_name       second_name   2020   2021   2022   2023   2024  \
# 383         Trent  Alexander-Arnold  0.003  0.004  0.004  0.002  0.002
# 260          Matt           Doherty  0.002  0.006  0.000  0.000  0.000
# 19         Andrew         Robertson  0.002  0.004  0.003  0.001  0.000
# 216  Konstantinos          Tsimikas  0.000  0.002  0.005  0.004  0.000
# 311         Pedro             Porro    NaN    NaN  0.003  0.003  0.000
# ..            ...               ...    ...    ...    ...    ...    ...
# 215  Konstantinos        Mavropanos    NaN    NaN    NaN  0.000  0.000
# 28           Axel            Disasi    NaN    NaN    NaN  0.000  0.000
# 48         Calvin            Bassey    NaN    NaN    NaN  0.000  0.000
# 309           Pau            Torres    NaN    NaN    NaN  0.000  0.000
# 232         Lewis              Hall    NaN    NaN    NaN  0.000  0.000
#
#      chance_to_play  prediction_linear  prediction_linear_score  \
# 383             100          2.884e-03                    0.148
# 260             100         -8.078e-04                    0.309
# 19              100          1.553e-03                    0.422
# 216             100          7.069e-03                   -1.239
# 311             100          2.528e-03                   -0.396
# ..              ...                ...                      ...
# 215             100          0.000e+00                    1.000
# 28              100          0.000e+00                    1.000
# 48              100          0.000e+00                    1.000
# 309             100          0.000e+00                    1.000
# 232             100          0.000e+00                    1.000
#
#      prediction_svr  prediction_svr_score  overperformed_assists
# 383           0.003                -0.103                  -1.00
# 260           0.003                -0.396                  -0.01
# 19            0.003                -0.140                  -0.13
# 216           0.003                -0.011                  -0.01
# 311           0.003                -0.500                  -0.32
# ..              ...                   ...                    ...
# 215           0.000                 1.000                   0.00
# 28            0.000                 1.000                   0.00
# 48            0.000                 1.000                  -0.03
# 309           0.000                 1.000                  -0.01
# 232           0.000                 1.000                  -0.02
#
# [75 rows x 13 columns]

# %%
# mix in player stats
defs = main.player_type_for_year(main.current_year, player_type="DEF")
player_info = pd.merge(
      left=def_data,
      right=defs,
      how='left',
      left_on=['first_name', 'second_name'],
      right_on=['first_name', 'second_name'],
  )
player_custom_info = player_info[['first_name', 'second_name', main.current_year, 'prediction_linear', 'prediction_svr', 'overperformed_assists', 'now_cost', 'goals_conceded', 'minutes', 'assists', 'total_points', 'influence', 'creativity', 'bonus', 'bps','selected_by_percent', ]]
player_custom_info.head()
# Out:
#      first_name       second_name   2024  prediction_linear  prediction_svr  \
# 0         Trent  Alexander-Arnold  0.002          2.884e-03           0.003
# 1          Matt           Doherty  0.000         -8.078e-04           0.003
# 2        Andrew         Robertson  0.000          1.553e-03           0.003
# 3  Konstantinos          Tsimikas  0.000          7.069e-03           0.003
# 4         Pedro             Porro  0.000          2.528e-03           0.003
#
#    overperformed_assists  now_cost  goals_conceded  minutes  assists  \
# 0                  -1.00        71               2      492        1
# 1                  -0.01        44               9      208        0
# 2                  -0.13        60               2      502        0
# 3                  -0.01        47               0       33        0
# 4                  -0.32        55               5      537        0
#
#    total_points  influence  creativity  bonus  bps  selected_by_percent
# 0            33      105.4       199.9      4  122                 32.1
# 1             2       40.8        16.0      0    2                  0.2
# 2            27       68.4       158.2      0  131                  7.2
# 3             3        6.6         2.1      0   11                  0.2
# 4            25      165.6       189.4      1  116                 29.8
